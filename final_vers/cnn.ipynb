# %% [markdown]
# ## Load the following dependencies

# %%
import os
import cv2
import json
import random
import re
import numpy as np
from PIL import Image
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras import regularizers

from tensorflow.keras.layers import (
    Dense, Conv2D, MaxPool2D, 
    Flatten, Dropout, BatchNormalization,
)
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tensorflow.keras.preprocessing import image as image_utils
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from sklearn.model_selection import train_test_split
from keras import backend as K

# %% [markdown]
# ## Coordinate appointing

# %%
# Groups coordinates of Waldo with the image
def coord_Data_Appointing(dataset, coord_file, w, binary, hasFile):
    # Opens the coordinates file
    if(hasFile == True):
        with open(coord_file, 'r') as f:
            coords = json.load(f)
    imgData_pairs = []
    imgDirect = os.path.dirname(dataset[0][0])
    # Retrieves the image name and the coordinates
    # Appends them together and preps them for coord appointing
    for img in dataset:
        imgPath = img[0]
        imgName = os.path.basename(imgPath)
        if(imgName != '.DS_Store'):
            pattern = r'\d+'
            digits = re.findall(pattern, imgName)
            if len(digits[0]) == 1:
                digits[0] = '0' + digits[0]
            imgData_pairs.append((imgName, digits)) 

    imgData_pairs = sorted(imgData_pairs, key=lambda x: x[1])

    # Coordinates are assigned to the image
    for img in imgData_pairs:
        imgName = img[0]
        # Get coords
        xPos = -w
        yPos = -w
        if hasFile == True:
            # issue?
            for item in coords[str(int(w))][str(int(img[1][0]))]:
                if(item["x"] == (img[1][1]) and item["y"] == (img[1][2])):
                    xPos = item["x_px"] / 64
                    yPos = item["y_px"] / 64
                    break

        xyCoords = [xPos, yPos]
        dataIndx = dataset.index((imgDirect + '/' + imgName, binary))
        
        temp = list(dataset[dataIndx])
        temp.append(xyCoords)
        dataset[dataIndx] = tuple(temp)

# %% [markdown]
# ## Splitting the data correctly

# %%
# Splits the data into training, validation, and testing sets
# STATUS: COMPLETE?
def data_splitting(dir1, dir1_1, dir1_2, dir2, w):
    # Each directory (waldo, not waldo) are given a binary classification
    sec1 = [(os.path.join(dir1, f), 0) for f in os.listdir(dir1)]
    sec1_1 = [(os.path.join(dir1_1, f), 0) for f in os.listdir(dir1_1)]
    sec1_2 = [(os.path.join(dir1_2, f), 0) for f in os.listdir(dir1_2)]
    sec2 = [(os.path.join(dir2, f), 1) for f in os.listdir(dir2)]

    coordsFile = os.path.join('Hey-Waldo-master', 'data.json')
    print(type(sec1))
    coord_Data_Appointing(sec1, coordsFile, w, 0, True)
    # =============
    # EXPERIMENTAL
    coord_Data_Appointing(sec1_1, coordsFile, w, 0, True)
    coord_Data_Appointing(sec1_2, coordsFile, w, 0, True)
    # EXPERIMENTAL
    # =============
    coord_Data_Appointing(sec2, coordsFile, w, 1, False)
    
    # Combines both sets and splits them into training, validation, and testing sets
    # 70% training, 20% validation, 10% testing
    #dataset = sec1 + sec1_1 + sec1_2 + sec2
    container = []
    for j in range(41):
        container = container + sec1 + sec1_1 + sec1_2

    dataset = container + sec2
    
    #dataset = sec1 + sec2
    train, test = train_test_split(dataset, test_size=0.3, random_state=42)
    valid, test = train_test_split(test, test_size=0.33, random_state=42)
    return train, valid, test

# %% [markdown]
# ## Adjust the data to the correct input for the model

# %%
# Adjusts the data to the appropriate size
def dataAdjusting(imgDataset, width, height):
    imgs = []
    coords = []
    for imgPath in imgDataset:
        if(os.path.basename(imgPath[0]) != '.DS_Store'):
            img = cv2.imread(imgPath[0])
            img = cv2.resize(img, (width, height))
            img = img / 255.0
            imgs.append(img)

            normCoords = [(imgPath[2][0])/width, (imgPath[2][1])/height]
            coords.append(normCoords)

    imgs = np.array(imgs)
    #coords = (np.array(coords))/(width * height)
    coords = (np.array(coords))

    return imgs, coords

def predictions(imgPath, width, height, model):
    image = image_utils.load_img(imgPath, target_size=(width, height))
    image = image_utils.img_to_array(image)
    image = image.reshape(1,width,height,3)
    image = preprocess_input(image)
    preds = model.predict(image)
    return preds

# %%
#######################################################################
#######################################################################
# START OF PROGRAM
#######################################################################
#######################################################################

# Combining the data and splitting into the appropriate sizes
# STATUS: INCOMPLETE
waldo_dir = os.path.join('Hey-Waldo-master', '64', 'waldo')
waldo_bw_dir = os.path.join('Hey-Waldo-master', '64-bw', 'waldo')
waldo_grey_dir = os.path.join('Hey-Waldo-master', '64-gray', 'waldo')
not_waldo_dir = os.path.join('Hey-Waldo-master', '64-copy', 'notwaldo')

# Current step is in the works
trainingSet, validSet, testingSet = data_splitting(waldo_dir, waldo_bw_dir, waldo_grey_dir, not_waldo_dir, 64)

print(f"Training Set: {len(trainingSet)}")
print(f"Validation Set: {len(validSet)}")
print(f"Testing Set: {len(testingSet)}")


#######################################################################
# Gets the image size parameters
# STATUS: INCOMPLETE
imgPath = os.path.join('Hey-Waldo-master', '64', 'waldo', '1_1_1.jpg')
imgPath = testingSet[0][0]

img = Image.open(imgPath)
width = img.width
height = img.height
imageSize = (width, height)

xTrain, yTrain = dataAdjusting(trainingSet, width, height)
xValid, yValid = dataAdjusting(validSet, width, height)
xTest, yTest = dataAdjusting(testingSet, width, height)

imgGen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest")
imgGen.fit(xTrain)
# Out:
# <class 'list'>
# Training Set: 3322
# Validation Set: 954
# Testing Set: 470

# %%
print(len(testingSet))
testingSet[468][2]
# Out:
# 470
# [6.0, 3.0]

# %% [markdown]
# ## Modified CNN model & Pretrained CNN model implementation

# %%
#######################################################################
# CNN Model based from NVIDIA Code with modificiations

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(width, height, 3)))
model.add(MaxPool2D(2, 2))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPool2D(2, 2))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPool2D(2, 2))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(MaxPool2D(2, 2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(2, activation='linear'))  # Two output neurons for the x and y coordinates

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(xTrain, yTrain , validation_data=(xValid, yValid), 
          epochs=10, batch_size=4)

# ADDING A NEW MODEL
base_model = keras.applications.VGG16(
    weights='imagenet',
    input_shape=(width, height, 3),
    include_top=False
)
base_model.trainable = True

inputs = keras.Input(shape=(width, height, 3))
x = base_model(inputs, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
outputs = keras.layers.Dense(2)(x)
vgg16_model = keras.Model(inputs, outputs)

vgg16_model.compile(optimizer='adam', loss='mean_squared_error')
vgg16_model.fit(xTrain, yTrain , validation_data=(xValid, yValid), 
          epochs=10, batch_size=4)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Epoch 1/10
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 46s 55ms/step - loss: 0.0595 - val_loss: 0.0103
# Epoch 2/10
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 46s 55ms/step - loss: 0.0069 - val_loss: 0.0049
# Epoch 3/10
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 50s 60ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 4/10
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 55s 66ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 5/10
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 48s 58ms/step - loss: 8.2924e-04 - val_loss: 0.0032
# Epoch 6/10
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 47s 57ms/step - loss: 9.6736e-04 - val_loss: 0.0024
# Epoch 7/10
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 51s 62ms/step - loss: 7.2731e-04 - val_loss: 0.0024
# Epoch 8/10
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 55s 66ms/step - loss: 6.2865e-04 - val_loss: 0.0020
# Epoch 9/10
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 55s 66ms/step - loss: 4.8964e-04 - val_loss: 0.0019
# Epoch 10/10
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 57s 69ms/step - loss: 5.1322e-04 - val_loss: 0.0025

# %% [markdown]
# ## Testing with the Modified model

# %%
# TESTING WITH TWO MODELS
xValError = 0
yValError = 0
x_errorPercentage = 0
y_errorPercentage = 0
print("\n\n=== === ===\nNOW TESTING WITH WALDO - Scratch Model")
for number in range(len(testingSet)):
    imgResults = predictions(testingSet[number][0], width, height, model)
    print(f"Image: {testingSet[number][0]} \Actual Results: {testingSet[number][2]}")
    print(f"Predicted Results: {imgResults}\n")

    xValError = imgResults[0][0] - testingSet[number][2][0]
    yValError = imgResults[0][1] - testingSet[number][2][1]

    x_errorPercentage += (xValError/testingSet[number][2][0]) * 100
    y_errorPercentage += (yValError/testingSet[number][2][1]) * 100


print(f"X Error: {x_errorPercentage/len(testingSet)}")
print(f"Y Error: {y_errorPercentage/len(testingSet)}")
# Out:
# === === ===
# NOW TESTING WITH WALDO - Scratch Model
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/7_12_5.jpg
# Predicted Results: [12.0, 5.0]
# Predicted Results: [[11.976232   2.6084356]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/4_2_12.jpg
# Predicted Results: [2.0, 12.0]
# Predicted Results: [[6.949501  0.7677355]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/18_15_6.jpg
# Predicted Results: [15.0, 6.0]
# Predicted Results: [[-0.5483464 -2.1481595]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/10_15_4.jpg
# Predicted Results: [15.0, 4.0]
# Predicted Results: [[8.4243765 4.0091696]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_5_2.jpg
# Predicted Results: [5.0, 2.0]
# Predicted Results: [[-0.13280642 -1.482341  ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/12_2_2.jpg
# Predicted Results: [2.0, 2.0]
# Predicted Results: [[-3.8551207 -1.7458522]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64-gray/waldo/12_2_1.jpg
# Predicted Results: [2.0, 1.0]
# Predicted Results: [[5.693458  1.3600113]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/12_2_2.jpg
# Predicted Results: [2.0, 2.0]
# Predicted Results: [[ 7.7577877  -0.21797228]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_15_6.jpg
# Predicted Results: [15.0, 6.0]
# Predicted Results: [[ 4.642968  -2.3218722]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/12_2_2.jpg
# Predicted Results: [2.0, 2.0]
# Predicted Results: [[-0.552799   1.3553569]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_14_6.jpg
# Predicted Results: [14.0, 6.0]
# Predicted Results: [[0.70133305 3.1975052 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_6_3.jpg
# Predicted Results: [6.0, 3.0]
# Predicted Results: [[ 0.68498087 -0.7220559 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/9_0_11.jpg
# Predicted Results: [0.0, 11.0]
# Predicted Results: [[ 0.34914482 -0.868013  ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/6_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[ 9.42163  -2.143921]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64/waldo/7_12_5.jpg
# Predicted Results: [12.0, 5.0]
# Predicted Results: [[3.727567  1.0649352]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/9_9_5.jpg
# Predicted Results: [9.0, 5.0]
# Predicted Results: [[0.3244741 2.1683125]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/5_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[1.8145738  0.03419185]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_9_5.jpg
# Predicted Results: [9.0, 5.0]
# Predicted Results: [[7.7088304 4.154973 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/4_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[-0.6281724 -0.5800538]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/19_0_7.jpg
# Predicted Results: [0.0, 7.0]
# Predicted Results: [[-4.964349   1.6906314]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_0_11.jpg
# Predicted Results: [0.0, 11.0]
# Predicted Results: [[4.2041817 5.897897 ]]
# /var/folders/fr/1q2qc89926lc3r6mb8jjx_tr0000gn/T/ipykernel_55496/3662526275.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   x_errorPercentage += (xValError/testingSet[number][2][0]) * 100
# /var/folders/fr/1q2qc89926lc3r6mb8jjx_tr0000gn/T/ipykernel_55496/3662526275.py:15: RuntimeWarning: invalid value encountered in scalar add
#   x_errorPercentage += (xValError/testingSet[number][2][0]) * 100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/1_4_6.jpg
# Predicted Results: [4.0, 6.0]
# Predicted Results: [[5.3260612 3.1218555]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/2_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[1.3542967 2.944714 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/2_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[1.3542967 2.944714 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/5_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 6.0942698 -3.5112424]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/2_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[ 6.6933675 -0.5889721]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/11_6_11.jpg
# Predicted Results: [6.0, 11.0]
# Predicted Results: [[ 5.909622   -0.07680488]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[-2.9302397   0.07167363]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/5_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 2.527135  -1.5050011]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/17_13_5.jpg
# Predicted Results: [13.0, 5.0]
# Predicted Results: [[ 1.3105055  -0.12141871]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/14_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[-0.79997015 -1.6956223 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/3_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[ 2.9564867 -0.8764258]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_2_15.jpg
# Predicted Results: [2.0, 15.0]
# Predicted Results: [[-2.370562  3.644282]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/19_0_7.jpg
# Predicted Results: [0.0, 7.0]
# Predicted Results: [[-2.7070136  2.6798644]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/18_15_7.jpg
# Predicted Results: [15.0, 7.0]
# Predicted Results: [[ 5.702038  -1.6705041]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/1_4_7.jpg
# Predicted Results: [4.0, 7.0]
# Predicted Results: [[-0.4547515  -0.17773676]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_15_6.jpg
# Predicted Results: [15.0, 6.0]
# Predicted Results: [[ 4.642968  -2.3218722]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/4_2_12.jpg
# Predicted Results: [2.0, 12.0]
# Predicted Results: [[ 0.77535963 -0.16678524]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/18_15_6.jpg
# Predicted Results: [15.0, 6.0]
# Predicted Results: [[-0.5483464 -2.1481595]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/14_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[-4.794486  -3.8610256]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/14_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[ 4.8501725 -2.2102814]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[ 4.1067863 -1.7104278]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/9_5_5.jpg
# Predicted Results: [5.0, 5.0]
# Predicted Results: [[ 2.3374197 -1.2284641]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/5_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[4.337042 2.093544]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Image: Hey-Waldo-master/64-bw/waldo/19_0_7.jpg
# Predicted Results: [0.0, 7.0]
# Predicted Results: [[-4.964349   1.6906314]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_2_14.jpg
# Predicted Results: [2.0, 14.0]
# Predicted Results: [[-2.8981903 -4.103835 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/19_0_7.jpg
# Predicted Results: [0.0, 7.0]
# Predicted Results: [[-3.9823105   0.22890338]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/16_10_4.jpg
# Predicted Results: [10.0, 4.0]
# Predicted Results: [[-0.6358063 -1.3255103]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_2_15.jpg
# Predicted Results: [2.0, 15.0]
# Predicted Results: [[0.02298737 0.14226389]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/9_9_5.jpg
# Predicted Results: [9.0, 5.0]
# Predicted Results: [[5.308105  1.3483338]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/9_0_12.jpg
# Predicted Results: [0.0, 12.0]
# Predicted Results: [[0.4168637  0.20525587]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[-2.9302397   0.07167363]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/11_6_11.jpg
# Predicted Results: [6.0, 11.0]
# Predicted Results: [[ 5.909622   -0.07680488]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/2_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[1.8145738  0.03419185]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/9_0_12.jpg
# Predicted Results: [0.0, 12.0]
# Predicted Results: [[5.713205 4.486401]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_5_5.jpg
# Predicted Results: [5.0, 5.0]
# Predicted Results: [[12.093458  -0.6850338]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/5_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 6.0942698 -3.5112424]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/10_15_4.jpg
# Predicted Results: [15.0, 4.0]
# Predicted Results: [[ 9.507411 10.088164]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_5_2.jpg
# Predicted Results: [5.0, 2.0]
# Predicted Results: [[-0.13280642 -1.482341  ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/12_2_2.jpg
# Predicted Results: [2.0, 2.0]
# Predicted Results: [[-0.552799   1.3553569]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/12_2_1.jpg
# Predicted Results: [2.0, 1.0]
# Predicted Results: [[-1.3872547  4.311285 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_14_7.jpg
# Predicted Results: [14.0, 7.0]
# Predicted Results: [[ 8.308334  -1.0567727]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64/waldo/17_13_5.jpg
# Predicted Results: [13.0, 5.0]
# Predicted Results: [[ 1.3105055  -0.12141871]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/11_6_11.jpg
# Predicted Results: [6.0, 11.0]
# Predicted Results: [[ 8.40538   -2.4651904]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/12_2_1.jpg
# Predicted Results: [2.0, 1.0]
# Predicted Results: [[5.693458  1.3600113]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/12_2_1.jpg
# Predicted Results: [2.0, 1.0]
# Predicted Results: [[-5.2387567  1.8774984]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/16_10_4.jpg
# Predicted Results: [10.0, 4.0]
# Predicted Results: [[-0.6358063 -1.3255103]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/18_14_7.jpg
# Predicted Results: [14.0, 7.0]
# Predicted Results: [[1.1202493 1.8061571]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/1_4_6.jpg
# Predicted Results: [4.0, 6.0]
# Predicted Results: [[10.212104  4.632729]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_0_12.jpg
# Predicted Results: [0.0, 12.0]
# Predicted Results: [[5.860545 3.487481]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/12_3_12.jpg
# Predicted Results: [3.0, 12.0]
# Predicted Results: [[11.104501  -1.8621774]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_5_3.jpg
# Predicted Results: [5.0, 3.0]
# Predicted Results: [[-2.9718513  2.041585 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_5_3.jpg
# Predicted Results: [5.0, 3.0]
# Predicted Results: [[-2.9718513  2.041585 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/2_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[4.337042 2.093544]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_2_14.jpg
# Predicted Results: [2.0, 14.0]
# Predicted Results: [[-2.8981903 -4.103835 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[0.9085183 1.5087204]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/6_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[ 9.42163  -2.143921]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/6_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[ 9.42163  -2.143921]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/19_0_6.jpg
# Predicted Results: [0.0, 6.0]
# Predicted Results: [[1.6876986 1.4104084]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/18_2_15.jpg
# Predicted Results: [2.0, 15.0]
# Predicted Results: [[-2.5762086 -0.5327344]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/10_15_4.jpg
# Predicted Results: [15.0, 4.0]
# Predicted Results: [[ 9.507411 10.088164]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_14_7.jpg
# Predicted Results: [14.0, 7.0]
# Predicted Results: [[2.2272606 2.0120182]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/1_4_6.jpg
# Predicted Results: [4.0, 6.0]
# Predicted Results: [[5.934491  2.7547665]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_0_10.jpg
# Predicted Results: [0.0, 10.0]
# Predicted Results: [[6.6144123  0.66751194]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/4_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[14.7992735  2.3293939]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/9_0_11.jpg
# Predicted Results: [0.0, 11.0]
# Predicted Results: [[ 0.34914482 -0.868013  ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64/waldo/9_9_5.jpg
# Predicted Results: [9.0, 5.0]
# Predicted Results: [[0.3244741 2.1683125]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/2_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[1.3542967 2.944714 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-copy/notwaldo/1_0_10.jpg
# Predicted Results: [-64, -64]
# Predicted Results: [[-7.1837935 -2.599154 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/19_0_7.jpg
# Predicted Results: [0.0, 7.0]
# Predicted Results: [[-2.7070136  2.6798644]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/19_0_6.jpg
# Predicted Results: [0.0, 6.0]
# Predicted Results: [[1.6876986 1.4104084]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/6_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[ 2.9564867 -0.8764258]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_15_6.jpg
# Predicted Results: [15.0, 6.0]
# Predicted Results: [[ 4.642968  -2.3218722]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Image: Hey-Waldo-master/64-bw/waldo/11_6_11.jpg
# Predicted Results: [6.0, 11.0]
# Predicted Results: [[ 8.663647  -3.3244703]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_5_2.jpg
# Predicted Results: [5.0, 2.0]
# Predicted Results: [[10.632532 -2.267828]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Image: Hey-Waldo-master/64-bw/waldo/11_6_11.jpg
# Predicted Results: [6.0, 11.0]
# Predicted Results: [[ 8.663647  -3.3244703]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Image: Hey-Waldo-master/64-gray/waldo/4_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[-0.6281724 -0.5800538]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/4_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[-0.6281724 -0.5800538]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/6_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[ 9.42163  -2.143921]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Image: Hey-Waldo-master/64/waldo/9_5_5.jpg
# Predicted Results: [5.0, 5.0]
# Predicted Results: [[ 2.3374197 -1.2284641]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/13_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[-2.9302397   0.07167363]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/3_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[4.950756  0.7555351]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/4_2_12.jpg
# Predicted Results: [2.0, 12.0]
# Predicted Results: [[1.2590833 1.9354737]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_14_6.jpg
# Predicted Results: [14.0, 6.0]
# Predicted Results: [[0.70133305 3.1975052 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_0_10.jpg
# Predicted Results: [0.0, 10.0]
# Predicted Results: [[6.6144123  0.66751194]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/11_6_11.jpg
# Predicted Results: [6.0, 11.0]
# Predicted Results: [[ 5.909622   -0.07680488]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/17_13_5.jpg
# Predicted Results: [13.0, 5.0]
# Predicted Results: [[ 1.3105055  -0.12141871]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_5_3.jpg
# Predicted Results: [5.0, 3.0]
# Predicted Results: [[-2.9718513  2.041585 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/14_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[ 4.8501725 -2.2102814]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_2_15.jpg
# Predicted Results: [2.0, 15.0]
# Predicted Results: [[-2.370562  3.644282]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/12_3_12.jpg
# Predicted Results: [3.0, 12.0]
# Predicted Results: [[4.692319  1.1656272]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/1_4_7.jpg
# Predicted Results: [4.0, 7.0]
# Predicted Results: [[ 0.10978746 -1.1472211 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/16_10_4.jpg
# Predicted Results: [10.0, 4.0]
# Predicted Results: [[5.285189 5.161618]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/2_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 2.527135  -1.5050011]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_5_2.jpg
# Predicted Results: [5.0, 2.0]
# Predicted Results: [[-0.13280642 -1.482341  ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/4_2_12.jpg
# Predicted Results: [2.0, 12.0]
# Predicted Results: [[6.949501  0.7677355]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/2_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[ 6.6933675 -0.5889721]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_6_2.jpg
# Predicted Results: [6.0, 2.0]
# Predicted Results: [[ 1.978729   -0.26886368]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/10_15_4.jpg
# Predicted Results: [15.0, 4.0]
# Predicted Results: [[8.4243765 4.0091696]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/14_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[ 4.8501725 -2.2102814]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/16_10_4.jpg
# Predicted Results: [10.0, 4.0]
# Predicted Results: [[5.285189 5.161618]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_5_2.jpg
# Predicted Results: [5.0, 2.0]
# Predicted Results: [[ 7.0050464 -2.8016672]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64-gray/waldo/10_15_4.jpg
# Predicted Results: [15.0, 4.0]
# Predicted Results: [[8.4243765 4.0091696]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/5_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[ 6.6933675 -0.5889721]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/6_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[ 2.9564867 -0.8764258]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/6_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[ 9.42163  -2.143921]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/9_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[5.7950115 4.374298 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[-2.9302397   0.07167363]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_6_3.jpg
# Predicted Results: [6.0, 3.0]
# Predicted Results: [[ 0.68498087 -0.7220559 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/2_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[1.3542967 2.944714 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/7_12_5.jpg
# Predicted Results: [12.0, 5.0]
# Predicted Results: [[3.727567  1.0649352]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_6_2.jpg
# Predicted Results: [6.0, 2.0]
# Predicted Results: [[-0.7114229  0.5209024]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/18_15_6.jpg
# Predicted Results: [15.0, 6.0]
# Predicted Results: [[-0.5483464 -2.1481595]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/9_5_5.jpg
# Predicted Results: [5.0, 5.0]
# Predicted Results: [[7.346023  1.5540237]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/18_14_6.jpg
# Predicted Results: [14.0, 6.0]
# Predicted Results: [[0.15478075 1.8321922 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/12_3_12.jpg
# Predicted Results: [3.0, 12.0]
# Predicted Results: [[11.104501  -1.8621774]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/3_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[ 2.9564867 -0.8764258]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/1_4_7.jpg
# Predicted Results: [4.0, 7.0]
# Predicted Results: [[-0.4547515  -0.17773676]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/18_14_6.jpg
# Predicted Results: [14.0, 6.0]
# Predicted Results: [[0.15478075 1.8321922 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/9_5_5.jpg
# Predicted Results: [5.0, 5.0]
# Predicted Results: [[7.346023  1.5540237]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_0_12.jpg
# Predicted Results: [0.0, 12.0]
# Predicted Results: [[5.860545 3.487481]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/12_2_1.jpg
# Predicted Results: [2.0, 1.0]
# Predicted Results: [[-5.2387567  1.8774984]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_6_3.jpg
# Predicted Results: [6.0, 3.0]
# Predicted Results: [[3.3480587 1.2005892]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Image: Hey-Waldo-master/64-bw/waldo/4_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[14.7992735  2.3293939]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Image: Hey-Waldo-master/64-bw/waldo/19_0_7.jpg
# Predicted Results: [0.0, 7.0]
# Predicted Results: [[-4.964349   1.6906314]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64/waldo/13_1_1.jpg
# Predicted Results: [1.0, 1.0]
# Predicted Results: [[ 5.055166   -0.30988884]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/2_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[ 6.6933675 -0.5889721]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/9_9_5.jpg
# Predicted Results: [9.0, 5.0]
# Predicted Results: [[0.3244741 2.1683125]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_5_3.jpg
# Predicted Results: [5.0, 3.0]
# Predicted Results: [[-2.5602849   0.23273158]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/1_4_7.jpg
# Predicted Results: [4.0, 7.0]
# Predicted Results: [[5.5914345 1.0157871]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/6_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[ 2.9564867 -0.8764258]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_6_2.jpg
# Predicted Results: [6.0, 2.0]
# Predicted Results: [[ 1.978729   -0.26886368]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_15_7.jpg
# Predicted Results: [15.0, 7.0]
# Predicted Results: [[5.483981  3.3992043]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_15_7.jpg
# Predicted Results: [15.0, 7.0]
# Predicted Results: [[11.960971   1.1161952]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Image: Hey-Waldo-master/64-gray/waldo/9_0_11.jpg
# Predicted Results: [0.0, 11.0]
# Predicted Results: [[-0.08015871  0.22201443]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_1_1.jpg
# Predicted Results: [1.0, 1.0]
# Predicted Results: [[ 5.055166   -0.30988884]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_6_2.jpg
# Predicted Results: [6.0, 2.0]
# Predicted Results: [[ 1.978729   -0.26886368]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_6_3.jpg
# Predicted Results: [6.0, 3.0]
# Predicted Results: [[0.75995433 0.9369613 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_0_10.jpg
# Predicted Results: [0.0, 10.0]
# Predicted Results: [[6.6144123  0.66751194]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/9_5_5.jpg
# Predicted Results: [5.0, 5.0]
# Predicted Results: [[7.346023  1.5540237]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/12_3_12.jpg
# Predicted Results: [3.0, 12.0]
# Predicted Results: [[4.692319  1.1656272]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/12_2_2.jpg
# Predicted Results: [2.0, 2.0]
# Predicted Results: [[ 7.7577877  -0.21797228]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/4_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[-0.6281724 -0.5800538]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/1_4_6.jpg
# Predicted Results: [4.0, 6.0]
# Predicted Results: [[5.3260612 3.1218555]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_5_2.jpg
# Predicted Results: [5.0, 2.0]
# Predicted Results: [[ 7.0050464 -2.8016672]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/5_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[1.3542967 2.944714 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_1_1.jpg
# Predicted Results: [1.0, 1.0]
# Predicted Results: [[ 3.6722288 -2.626971 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_6_3.jpg
# Predicted Results: [6.0, 3.0]
# Predicted Results: [[0.75995433 0.9369613 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_6_3.jpg
# Predicted Results: [6.0, 3.0]
# Predicted Results: [[ 0.68498087 -0.7220559 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/16_10_4.jpg
# Predicted Results: [10.0, 4.0]
# Predicted Results: [[5.285189 5.161618]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64-gray/waldo/14_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[ 4.8501725 -2.2102814]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_15_7.jpg
# Predicted Results: [15.0, 7.0]
# Predicted Results: [[11.960971   1.1161952]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Image: Hey-Waldo-master/64/waldo/18_14_6.jpg
# Predicted Results: [14.0, 6.0]
# Predicted Results: [[0.15478075 1.8321922 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_6_2.jpg
# Predicted Results: [6.0, 2.0]
# Predicted Results: [[-0.7114229  0.5209024]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/14_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[-0.79997015 -1.6956223 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/6_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[ 2.9564867 -0.8764258]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/6_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[ 9.42163  -2.143921]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/12_3_12.jpg
# Predicted Results: [3.0, 12.0]
# Predicted Results: [[4.692319  1.1656272]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/16_10_4.jpg
# Predicted Results: [10.0, 4.0]
# Predicted Results: [[5.285189 5.161618]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_5_3.jpg
# Predicted Results: [5.0, 3.0]
# Predicted Results: [[1.3727069 4.6043777]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_15_7.jpg
# Predicted Results: [15.0, 7.0]
# Predicted Results: [[11.960971   1.1161952]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_1_1.jpg
# Predicted Results: [1.0, 1.0]
# Predicted Results: [[ 5.055166   -0.30988884]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_15_6.jpg
# Predicted Results: [15.0, 6.0]
# Predicted Results: [[6.3419194 1.7683845]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_5_3.jpg
# Predicted Results: [5.0, 3.0]
# Predicted Results: [[1.3727069 4.6043777]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_9_5.jpg
# Predicted Results: [9.0, 5.0]
# Predicted Results: [[7.7088304 4.154973 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/2_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 6.0942698 -3.5112424]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/5_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[1.3542967 2.944714 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_0_12.jpg
# Predicted Results: [0.0, 12.0]
# Predicted Results: [[5.860545 3.487481]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_1_1.jpg
# Predicted Results: [1.0, 1.0]
# Predicted Results: [[ 5.055166   -0.30988884]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Image: Hey-Waldo-master/64-gray/waldo/9_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[19.16867   8.611516]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/4_2_12.jpg
# Predicted Results: [2.0, 12.0]
# Predicted Results: [[6.949501  0.7677355]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/5_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 6.0942698 -3.5112424]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_14_6.jpg
# Predicted Results: [14.0, 6.0]
# Predicted Results: [[3.842391 3.161396]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_5_3.jpg
# Predicted Results: [5.0, 3.0]
# Predicted Results: [[-2.5602849   0.23273158]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64-gray/waldo/4_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[-0.6281724 -0.5800538]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/4_2_12.jpg
# Predicted Results: [2.0, 12.0]
# Predicted Results: [[1.2590833 1.9354737]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/9_5_5.jpg
# Predicted Results: [5.0, 5.0]
# Predicted Results: [[ 2.3374197 -1.2284641]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/3_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[4.950756  0.7555351]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Image: Hey-Waldo-master/64/waldo/9_9_5.jpg
# Predicted Results: [9.0, 5.0]
# Predicted Results: [[0.3244741 2.1683125]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Image: Hey-Waldo-master/64/waldo/18_14_6.jpg
# Predicted Results: [14.0, 6.0]
# Predicted Results: [[0.15478075 1.8321922 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_5_3.jpg
# Predicted Results: [5.0, 3.0]
# Predicted Results: [[1.3727069 4.6043777]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_5_2.jpg
# Predicted Results: [5.0, 2.0]
# Predicted Results: [[ 7.0050464 -2.8016672]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_2_15.jpg
# Predicted Results: [2.0, 15.0]
# Predicted Results: [[-2.370562  3.644282]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/1_4_6.jpg
# Predicted Results: [4.0, 6.0]
# Predicted Results: [[10.212104  4.632729]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/12_2_2.jpg
# Predicted Results: [2.0, 2.0]
# Predicted Results: [[-0.552799   1.3553569]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/5_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[ 6.6933675 -0.5889721]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/5_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 2.527135  -1.5050011]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[-2.9302397   0.07167363]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/12_3_12.jpg
# Predicted Results: [3.0, 12.0]
# Predicted Results: [[11.104501  -1.8621774]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/18_14_6.jpg
# Predicted Results: [14.0, 6.0]
# Predicted Results: [[0.15478075 1.8321922 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/2_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[ 6.6933675 -0.5889721]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/5_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[4.337042 2.093544]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[0.9085183 1.5087204]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/14_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[ 4.8501725 -2.2102814]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/18_15_6.jpg
# Predicted Results: [15.0, 6.0]
# Predicted Results: [[-0.5483464 -2.1481595]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/14_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[-4.794486  -3.8610256]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_14_6.jpg
# Predicted Results: [14.0, 6.0]
# Predicted Results: [[0.70133305 3.1975052 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_6_2.jpg
# Predicted Results: [6.0, 2.0]
# Predicted Results: [[-0.7114229  0.5209024]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64-gray/waldo/9_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[19.16867   8.611516]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64/waldo/18_2_15.jpg
# Predicted Results: [2.0, 15.0]
# Predicted Results: [[-2.5762086 -0.5327344]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/3_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[ 9.42163  -2.143921]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/18_15_6.jpg
# Predicted Results: [15.0, 6.0]
# Predicted Results: [[-0.5483464 -2.1481595]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[ 4.1067863 -1.7104278]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_5_3.jpg
# Predicted Results: [5.0, 3.0]
# Predicted Results: [[-2.9718513  2.041585 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_5_3.jpg
# Predicted Results: [5.0, 3.0]
# Predicted Results: [[1.3727069 4.6043777]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/1_4_6.jpg
# Predicted Results: [4.0, 6.0]
# Predicted Results: [[5.934491  2.7547665]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/5_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[ 6.6933675 -0.5889721]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Image: Hey-Waldo-master/64-gray/waldo/2_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 2.527135  -1.5050011]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Image: Hey-Waldo-master/64/waldo/18_14_6.jpg
# Predicted Results: [14.0, 6.0]
# Predicted Results: [[0.15478075 1.8321922 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_14_6.jpg
# Predicted Results: [14.0, 6.0]
# Predicted Results: [[3.842391 3.161396]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_2_15.jpg
# Predicted Results: [2.0, 15.0]
# Predicted Results: [[-2.370562  3.644282]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/5_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[4.337042 2.093544]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/4_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[14.7992735  2.3293939]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_1_1.jpg
# Predicted Results: [1.0, 1.0]
# Predicted Results: [[ 3.6722288 -2.626971 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/16_10_4.jpg
# Predicted Results: [10.0, 4.0]
# Predicted Results: [[6.074726  4.7916613]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-copy/notwaldo/1_1_7.jpg
# Predicted Results: [-64, -64]
# Predicted Results: [[5.297197  1.2178533]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/11_6_11.jpg
# Predicted Results: [6.0, 11.0]
# Predicted Results: [[ 8.663647  -3.3244703]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/18_14_7.jpg
# Predicted Results: [14.0, 7.0]
# Predicted Results: [[1.1202493 1.8061571]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/9_9_5.jpg
# Predicted Results: [9.0, 5.0]
# Predicted Results: [[0.3244741 2.1683125]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/19_0_6.jpg
# Predicted Results: [0.0, 6.0]
# Predicted Results: [[1.6876986 1.4104084]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_2_14.jpg
# Predicted Results: [2.0, 14.0]
# Predicted Results: [[-2.8981903 -4.103835 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/5_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 2.527135  -1.5050011]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/5_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 2.527135  -1.5050011]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_1_1.jpg
# Predicted Results: [1.0, 1.0]
# Predicted Results: [[ 3.6722288 -2.626971 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_6_3.jpg
# Predicted Results: [6.0, 3.0]
# Predicted Results: [[0.75995433 0.9369613 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/16_10_4.jpg
# Predicted Results: [10.0, 4.0]
# Predicted Results: [[-0.6358063 -1.3255103]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/9_5_5.jpg
# Predicted Results: [5.0, 5.0]
# Predicted Results: [[ 2.3374197 -1.2284641]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_6_3.jpg
# Predicted Results: [6.0, 3.0]
# Predicted Results: [[ 0.68498087 -0.7220559 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Image: Hey-Waldo-master/64-bw/waldo/1_4_7.jpg
# Predicted Results: [4.0, 7.0]
# Predicted Results: [[ 0.10978746 -1.1472211 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_5_5.jpg
# Predicted Results: [5.0, 5.0]
# Predicted Results: [[12.093458  -0.6850338]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/2_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 2.527135  -1.5050011]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/19_0_7.jpg
# Predicted Results: [0.0, 7.0]
# Predicted Results: [[-4.964349   1.6906314]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/1_4_7.jpg
# Predicted Results: [4.0, 7.0]
# Predicted Results: [[ 0.10978746 -1.1472211 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_9_5.jpg
# Predicted Results: [9.0, 5.0]
# Predicted Results: [[7.7088304 4.154973 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64-gray/waldo/17_13_5.jpg
# Predicted Results: [13.0, 5.0]
# Predicted Results: [[ 6.714916  -3.6074033]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/12_3_12.jpg
# Predicted Results: [3.0, 12.0]
# Predicted Results: [[11.104501  -1.8621774]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/19_0_6.jpg
# Predicted Results: [0.0, 6.0]
# Predicted Results: [[1.6876986 1.4104084]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/5_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[1.8145738  0.03419185]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/6_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[ 9.42163  -2.143921]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/2_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[4.337042 2.093544]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/4_2_12.jpg
# Predicted Results: [2.0, 12.0]
# Predicted Results: [[6.949501  0.7677355]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_5_2.jpg
# Predicted Results: [5.0, 2.0]
# Predicted Results: [[-0.13280642 -1.482341  ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/11_6_11.jpg
# Predicted Results: [6.0, 11.0]
# Predicted Results: [[ 8.663647  -3.3244703]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/19_0_6.jpg
# Predicted Results: [0.0, 6.0]
# Predicted Results: [[9.447437   0.71227455]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Image: Hey-Waldo-master/64-gray/waldo/17_13_5.jpg
# Predicted Results: [13.0, 5.0]
# Predicted Results: [[ 6.714916  -3.6074033]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Image: Hey-Waldo-master/64-gray/waldo/5_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 2.527135  -1.5050011]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Image: Hey-Waldo-master/64-bw/waldo/16_10_4.jpg
# Predicted Results: [10.0, 4.0]
# Predicted Results: [[6.074726  4.7916613]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/18_2_14.jpg
# Predicted Results: [2.0, 14.0]
# Predicted Results: [[-1.3890196  2.054738 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/4_2_12.jpg
# Predicted Results: [2.0, 12.0]
# Predicted Results: [[1.2590833 1.9354737]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/12_2_1.jpg
# Predicted Results: [2.0, 1.0]
# Predicted Results: [[-5.2387567  1.8774984]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/12_2_2.jpg
# Predicted Results: [2.0, 2.0]
# Predicted Results: [[-3.8551207 -1.7458522]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/12_2_1.jpg
# Predicted Results: [2.0, 1.0]
# Predicted Results: [[-5.2387567  1.8774984]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_15_7.jpg
# Predicted Results: [15.0, 7.0]
# Predicted Results: [[5.483981  3.3992043]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Image: Hey-Waldo-master/64-gray/waldo/9_0_11.jpg
# Predicted Results: [0.0, 11.0]
# Predicted Results: [[-0.08015871  0.22201443]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_6_2.jpg
# Predicted Results: [6.0, 2.0]
# Predicted Results: [[-0.7114229  0.5209024]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/12_3_12.jpg
# Predicted Results: [3.0, 12.0]
# Predicted Results: [[7.0790954 1.2818484]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/2_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 2.527135  -1.5050011]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/19_0_7.jpg
# Predicted Results: [0.0, 7.0]
# Predicted Results: [[-2.7070136  2.6798644]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/9_5_5.jpg
# Predicted Results: [5.0, 5.0]
# Predicted Results: [[7.346023  1.5540237]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/2_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 6.0942698 -3.5112424]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/4_2_12.jpg
# Predicted Results: [2.0, 12.0]
# Predicted Results: [[ 0.77535963 -0.16678524]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_15_7.jpg
# Predicted Results: [15.0, 7.0]
# Predicted Results: [[11.960971   1.1161952]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/14_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[-0.79997015 -1.6956223 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/4_2_12.jpg
# Predicted Results: [2.0, 12.0]
# Predicted Results: [[6.949501  0.7677355]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/13_5_3.jpg
# Predicted Results: [5.0, 3.0]
# Predicted Results: [[-2.5602849   0.23273158]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_1_1.jpg
# Predicted Results: [1.0, 1.0]
# Predicted Results: [[ 5.055166   -0.30988884]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_5_5.jpg
# Predicted Results: [5.0, 5.0]
# Predicted Results: [[12.093458  -0.6850338]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_5_3.jpg
# Predicted Results: [5.0, 3.0]
# Predicted Results: [[-2.9718513  2.041585 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Image: Hey-Waldo-master/64/waldo/13_1_1.jpg
# Predicted Results: [1.0, 1.0]
# Predicted Results: [[ 5.055166   -0.30988884]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/18_2_14.jpg
# Predicted Results: [2.0, 14.0]
# Predicted Results: [[-1.3890196  2.054738 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/5_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 6.0942698 -3.5112424]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_5_3.jpg
# Predicted Results: [5.0, 3.0]
# Predicted Results: [[-2.5602849   0.23273158]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/2_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[ 6.6933675 -0.5889721]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/2_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 2.527135  -1.5050011]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/12_3_12.jpg
# Predicted Results: [3.0, 12.0]
# Predicted Results: [[7.0790954 1.2818484]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# ...
# Predicted Results: [0.0, 11.0]
# Predicted Results: [[-0.08015871  0.22201443]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Image: Hey-Waldo-master/64/waldo/19_0_7.jpg
# Predicted Results: [0.0, 7.0]
# Predicted Results: [[-3.9823105   0.22890338]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Image: Hey-Waldo-master/64/waldo/18_14_7.jpg
# Predicted Results: [14.0, 7.0]
# Predicted Results: [[1.1202493 1.8061571]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Image: Hey-Waldo-master/64/waldo/11_6_11.jpg
# Predicted Results: [6.0, 11.0]
# Predicted Results: [[ 5.909622   -0.07680488]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Image: Hey-Waldo-master/64/waldo/9_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[5.7950115 4.374298 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/10_15_4.jpg
# Predicted Results: [15.0, 4.0]
# Predicted Results: [[7.4535494 5.7440224]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/5_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[4.337042 2.093544]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_1_1.jpg
# Predicted Results: [1.0, 1.0]
# Predicted Results: [[ 3.6722288 -2.626971 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_2_15.jpg
# Predicted Results: [2.0, 15.0]
# Predicted Results: [[-2.370562  3.644282]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/12_3_12.jpg
# Predicted Results: [3.0, 12.0]
# Predicted Results: [[4.692319  1.1656272]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_5_2.jpg
# Predicted Results: [5.0, 2.0]
# Predicted Results: [[10.632532 -2.267828]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/7_12_5.jpg
# Predicted Results: [12.0, 5.0]
# Predicted Results: [[8.889845  2.7142828]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/11_6_11.jpg
# Predicted Results: [6.0, 11.0]
# Predicted Results: [[ 5.909622   -0.07680488]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_1_1.jpg
# Predicted Results: [1.0, 1.0]
# Predicted Results: [[ 3.6722288 -2.626971 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_14_6.jpg
# Predicted Results: [14.0, 6.0]
# Predicted Results: [[0.70133305 3.1975052 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/12_3_12.jpg
# Predicted Results: [3.0, 12.0]
# Predicted Results: [[7.0790954 1.2818484]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/2_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[1.8145738  0.03419185]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Image: Hey-Waldo-master/64-gray/waldo/4_2_12.jpg
# Predicted Results: [2.0, 12.0]
# Predicted Results: [[ 0.77535963 -0.16678524]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/4_2_12.jpg
# Predicted Results: [2.0, 12.0]
# Predicted Results: [[6.949501  0.7677355]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/12_2_1.jpg
# Predicted Results: [2.0, 1.0]
# Predicted Results: [[-5.2387567  1.8774984]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/12_2_1.jpg
# Predicted Results: [2.0, 1.0]
# Predicted Results: [[5.693458  1.3600113]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_1_1.jpg
# Predicted Results: [1.0, 1.0]
# Predicted Results: [[ 1.6072311 -0.912539 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_6_3.jpg
# Predicted Results: [6.0, 3.0]
# Predicted Results: [[3.3480587 1.2005892]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64/waldo/6_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[ 2.9564867 -0.8764258]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/9_0_11.jpg
# Predicted Results: [0.0, 11.0]
# Predicted Results: [[-0.08015871  0.22201443]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/1_4_7.jpg
# Predicted Results: [4.0, 7.0]
# Predicted Results: [[5.5914345 1.0157871]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/11_6_11.jpg
# Predicted Results: [6.0, 11.0]
# Predicted Results: [[ 5.909622   -0.07680488]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/10_15_4.jpg
# Predicted Results: [15.0, 4.0]
# Predicted Results: [[ 9.507411 10.088164]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64/waldo/9_0_12.jpg
# Predicted Results: [0.0, 12.0]
# Predicted Results: [[0.4168637  0.20525587]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/2_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[1.8145738  0.03419185]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_5_2.jpg
# Predicted Results: [5.0, 2.0]
# Predicted Results: [[10.632532 -2.267828]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/14_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[-4.794486  -3.8610256]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_9_5.jpg
# Predicted Results: [9.0, 5.0]
# Predicted Results: [[7.7088304 4.154973 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_9_5.jpg
# Predicted Results: [9.0, 5.0]
# Predicted Results: [[7.7088304 4.154973 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Image: Hey-Waldo-master/64/waldo/19_0_6.jpg
# Predicted Results: [0.0, 6.0]
# Predicted Results: [[1.6876986 1.4104084]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Image: Hey-Waldo-master/64-bw/waldo/4_2_12.jpg
# Predicted Results: [2.0, 12.0]
# Predicted Results: [[6.949501  0.7677355]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_0_12.jpg
# Predicted Results: [0.0, 12.0]
# Predicted Results: [[5.860545 3.487481]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/10_15_4.jpg
# Predicted Results: [15.0, 4.0]
# Predicted Results: [[8.4243765 4.0091696]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64-gray/waldo/3_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[4.950756  0.7555351]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/13_5_3.jpg
# Predicted Results: [5.0, 3.0]
# Predicted Results: [[-2.5602849   0.23273158]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_14_7.jpg
# Predicted Results: [14.0, 7.0]
# Predicted Results: [[2.2272606 2.0120182]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/9_0_12.jpg
# Predicted Results: [0.0, 12.0]
# Predicted Results: [[0.4168637  0.20525587]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/14_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[-0.79997015 -1.6956223 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/13_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[-2.9302397   0.07167363]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_5_5.jpg
# Predicted Results: [5.0, 5.0]
# Predicted Results: [[12.093458  -0.6850338]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_14_6.jpg
# Predicted Results: [14.0, 6.0]
# Predicted Results: [[0.70133305 3.1975052 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Image: Hey-Waldo-master/64-bw/waldo/10_15_4.jpg
# Predicted Results: [15.0, 4.0]
# Predicted Results: [[ 9.507411 10.088164]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/18_14_7.jpg
# Predicted Results: [14.0, 7.0]
# Predicted Results: [[1.1202493 1.8061571]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_6_2.jpg
# Predicted Results: [6.0, 2.0]
# Predicted Results: [[-0.7114229  0.5209024]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_2_14.jpg
# Predicted Results: [2.0, 14.0]
# Predicted Results: [[-2.8981903 -4.103835 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/11_6_11.jpg
# Predicted Results: [6.0, 11.0]
# Predicted Results: [[ 5.909622   -0.07680488]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_5_3.jpg
# Predicted Results: [5.0, 3.0]
# Predicted Results: [[1.3727069 4.6043777]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64-bw/waldo/1_4_7.jpg
# Predicted Results: [4.0, 7.0]
# Predicted Results: [[ 0.10978746 -1.1472211 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/11_6_11.jpg
# Predicted Results: [6.0, 11.0]
# Predicted Results: [[ 8.663647  -3.3244703]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/11_6_11.jpg
# Predicted Results: [6.0, 11.0]
# Predicted Results: [[ 8.663647  -3.3244703]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/1_4_7.jpg
# Predicted Results: [4.0, 7.0]
# Predicted Results: [[ 0.10978746 -1.1472211 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_6_2.jpg
# Predicted Results: [6.0, 2.0]
# Predicted Results: [[-0.7114229  0.5209024]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_0_10.jpg
# Predicted Results: [0.0, 10.0]
# Predicted Results: [[6.6144123  0.66751194]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[-2.9302397   0.07167363]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/9_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[5.7950115 4.374298 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Image: Hey-Waldo-master/64/waldo/13_6_3.jpg
# Predicted Results: [6.0, 3.0]
# Predicted Results: [[0.75995433 0.9369613 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_1_1.jpg
# Predicted Results: [1.0, 1.0]
# Predicted Results: [[ 1.6072311 -0.912539 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/16_10_4.jpg
# Predicted Results: [10.0, 4.0]
# Predicted Results: [[6.074726  4.7916613]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Image: Hey-Waldo-master/64/waldo/9_0_12.jpg
# Predicted Results: [0.0, 12.0]
# Predicted Results: [[0.4168637  0.20525587]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Image: Hey-Waldo-master/64-bw/waldo/16_10_4.jpg
# Predicted Results: [10.0, 4.0]
# Predicted Results: [[6.074726  4.7916613]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Image: Hey-Waldo-master/64-bw/waldo/2_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[ 6.6933675 -0.5889721]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_0_12.jpg
# Predicted Results: [0.0, 12.0]
# Predicted Results: [[5.860545 3.487481]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/19_0_6.jpg
# Predicted Results: [0.0, 6.0]
# Predicted Results: [[6.999186   0.31246138]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64/waldo/9_9_5.jpg
# Predicted Results: [9.0, 5.0]
# Predicted Results: [[0.3244741 2.1683125]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_14_7.jpg
# Predicted Results: [14.0, 7.0]
# Predicted Results: [[2.2272606 2.0120182]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/9_0_11.jpg
# Predicted Results: [0.0, 11.0]
# Predicted Results: [[ 0.34914482 -0.868013  ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/13_6_2.jpg
# Predicted Results: [6.0, 2.0]
# Predicted Results: [[0.18187761 2.2730556 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/4_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[14.7992735  2.3293939]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Image: Hey-Waldo-master/64-gray/waldo/12_2_1.jpg
# Predicted Results: [2.0, 1.0]
# Predicted Results: [[5.693458  1.3600113]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/1_4_6.jpg
# Predicted Results: [4.0, 6.0]
# Predicted Results: [[10.212104  4.632729]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/13_2_11.jpg
# Predicted Results: [2.0, 11.0]
# Predicted Results: [[-2.9302397   0.07167363]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Image: Hey-Waldo-master/64/waldo/9_1_12.jpg
# Predicted Results: [1.0, 12.0]
# Predicted Results: [[5.7950115 4.374298 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/17_13_5.jpg
# Predicted Results: [13.0, 5.0]
# Predicted Results: [[ 6.714916  -3.6074033]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/6_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[4.950756  0.7555351]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/5_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 2.527135  -1.5050011]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/5_7_3.jpg
# Predicted Results: [7.0, 3.0]
# Predicted Results: [[ 2.527135  -1.5050011]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64/waldo/17_13_5.jpg
# Predicted Results: [13.0, 5.0]
# Predicted Results: [[ 1.3105055  -0.12141871]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/9_0_10.jpg
# Predicted Results: [0.0, 10.0]
# Predicted Results: [[6.6144123  0.66751194]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_2_15.jpg
# Predicted Results: [2.0, 15.0]
# Predicted Results: [[0.02298737 0.14226389]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/1_4_7.jpg
# Predicted Results: [4.0, 7.0]
# Predicted Results: [[ 0.10978746 -1.1472211 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64/waldo/6_15_1.jpg
# Predicted Results: [15.0, 1.0]
# Predicted Results: [[ 2.9564867 -0.8764258]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-bw/waldo/12_2_2.jpg
# Predicted Results: [2.0, 2.0]
# Predicted Results: [[-0.552799   1.3553569]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/18_15_6.jpg
# Predicted Results: [15.0, 6.0]
# Predicted Results: [[6.3419194 1.7683845]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Image: Hey-Waldo-master/64-gray/waldo/4_2_12.jpg
# Predicted Results: [2.0, 12.0]
# Predicted Results: [[ 0.77535963 -0.16678524]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Image: Hey-Waldo-master/64-gray/waldo/12_2_2.jpg
# Predicted Results: [2.0, 2.0]
# Predicted Results: [[ 7.7577877  -0.21797228]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Image: Hey-Waldo-master/64-gray/waldo/13_6_2.jpg
# Predicted Results: [6.0, 2.0]
# Predicted Results: [[-0.7114229  0.5209024]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Image: Hey-Waldo-master/64-bw/waldo/10_15_4.jpg
# Predicted Results: [15.0, 4.0]
# Predicted Results: [[ 9.507411 10.088164]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Image: Hey-Waldo-master/64-bw/waldo/18_15_7.jpg
# Predicted Results: [15.0, 7.0]
# Predicted Results: [[11.960971   1.1161952]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Image: Hey-Waldo-master/64-gray/waldo/5_2_5.jpg
# Predicted Results: [2.0, 5.0]
# Predicted Results: [[4.337042 2.093544]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Image: Hey-Waldo-master/64-bw/waldo/7_12_5.jpg
# Predicted Results: [12.0, 5.0]
# Predicted Results: [[11.976232   2.6084356]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-gray/waldo/19_0_6.jpg
# Predicted Results: [0.0, 6.0]
# Predicted Results: [[6.999186   0.31246138]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Image: Hey-Waldo-master/64-bw/waldo/19_0_7.jpg
# Predicted Results: [0.0, 7.0]
# Predicted Results: [[-4.964349   1.6906314]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Image: Hey-Waldo-master/64-bw/waldo/13_6_3.jpg
# Predicted Results: [6.0, 3.0]
# Predicted Results: [[3.3480587 1.2005892]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Image: Hey-Waldo-master/64-gray/waldo/4_2_12.jpg
# Predicted Results: [2.0, 12.0]
# Predicted Results: [[ 0.77535963 -0.16678524]]
#
# X Error: nan
# Y Error: -90.84007600406257

# %% [markdown]
# ## Testing with the Pretrained Model

# %%
print("\n\n=== === ===\nNOW TESTING WITH WALDO - Pretrained Model")
xValError = 0
yValError = 0
x_errorPercentage = 0
y_errorPercentage = 0
for number in range(len(testingSet)):
    imgResults = predictions(testingSet[number][0], width, height, vgg16_model)
    print(f"\nImage: {testingSet[number][0]} \nActual Results: {testingSet[number][2]}")
    print(f"Predicted Results: {imgResults}\n")
    xValError = imgResults[0][0] - testingSet[number][2][0]
    yValError = imgResults[0][1] - testingSet[number][2][1]

    x_errorPercentage += (xValError/testingSet[number][2][0]) * 100
    y_errorPercentage += (yValError/testingSet[number][2][1]) * 100


print(f"X Error: {x_errorPercentage/len(testingSet)}")
print(f"Y Error: {y_errorPercentage/len(testingSet)}")
# Out:
# === === ===
# NOW TESTING WITH WALDO - Pretrained Model
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/7_12_5.jpg
# Actual Results: [12.0, 5.0]
# Predicted Results: [[  3.7519155 -28.917213 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/4_2_12.jpg
# Actual Results: [2.0, 12.0]
# Predicted Results: [[28.414469  -3.3929257]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_15_6.jpg
# Actual Results: [15.0, 6.0]
# Predicted Results: [[-7.824945  -3.7869995]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/10_15_4.jpg
# Actual Results: [15.0, 4.0]
# Predicted Results: [[28.339859 -4.547207]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_5_2.jpg
# Actual Results: [5.0, 2.0]
# Predicted Results: [[ -1.3438125 -20.836895 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/12_2_2.jpg
# Actual Results: [2.0, 2.0]
# Predicted Results: [[ 0.52303904 -4.3236833 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/12_2_1.jpg
# Actual Results: [2.0, 1.0]
# Predicted Results: [[ -8.144906 -16.997114]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/12_2_2.jpg
# Actual Results: [2.0, 2.0]
# Predicted Results: [[ 5.881581  -1.4955701]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_15_6.jpg
# Actual Results: [15.0, 6.0]
# Predicted Results: [[ 6.462901 -3.155094]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/12_2_2.jpg
# Actual Results: [2.0, 2.0]
# Predicted Results: [[-18.14499  -21.124977]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_14_6.jpg
# Actual Results: [14.0, 6.0]
# Predicted Results: [[25.224548 -8.477332]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_6_3.jpg
# Actual Results: [6.0, 3.0]
# Predicted Results: [[30.811079  8.402409]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_0_11.jpg
# Actual Results: [0.0, 11.0]
# Predicted Results: [[-8.682699 19.06496 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/6_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[ 14.964595 -25.172419]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/7_12_5.jpg
# Actual Results: [12.0, 5.0]
# Predicted Results: [[ -5.895302 -15.182343]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_9_5.jpg
# Actual Results: [9.0, 5.0]
# Predicted Results: [[-0.5118721  7.6138616]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/5_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[6.5579453 7.433178 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# /var/folders/fr/1q2qc89926lc3r6mb8jjx_tr0000gn/T/ipykernel_55496/3036007101.py:13: RuntimeWarning: divide by zero encountered in scalar divide
#   x_errorPercentage += (xValError/testingSet[number][2][0]) * 100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_9_5.jpg
# Actual Results: [9.0, 5.0]
# Predicted Results: [[14.581773  -5.1906223]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/4_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[31.69754 34.32759]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/19_0_7.jpg
# Actual Results: [0.0, 7.0]
# Predicted Results: [[17.134977   1.5754533]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_0_11.jpg
# Actual Results: [0.0, 11.0]
# Predicted Results: [[-0.93345135 -1.3815842 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/1_4_6.jpg
# Actual Results: [4.0, 6.0]
# Predicted Results: [[ 36.64828  -22.286839]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/2_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[-3.956001 -4.381799]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/2_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[-3.956001 -4.381799]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# /var/folders/fr/1q2qc89926lc3r6mb8jjx_tr0000gn/T/ipykernel_55496/3036007101.py:13: RuntimeWarning: invalid value encountered in scalar add
#   x_errorPercentage += (xValError/testingSet[number][2][0]) * 100
# Image: Hey-Waldo-master/64-bw/waldo/5_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[ -2.8112414 -19.725428 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/2_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[11.175315  -2.2395463]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/11_6_11.jpg
# Actual Results: [6.0, 11.0]
# Predicted Results: [[ -3.5849242 -16.537354 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[-57.37982  -31.610353]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/5_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[31.165857 14.265556]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64/waldo/17_13_5.jpg
# Actual Results: [13.0, 5.0]
# Predicted Results: [[10.69884    -0.94740134]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/14_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[-1.4413414 -4.5725775]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64/waldo/3_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[ -3.4591143 -10.621502 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_2_15.jpg
# Actual Results: [2.0, 15.0]
# Predicted Results: [[38.816643 14.112361]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/19_0_7.jpg
# Actual Results: [0.0, 7.0]
# Predicted Results: [[26.446602 18.607824]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_15_7.jpg
# Actual Results: [15.0, 7.0]
# Predicted Results: [[-20.192614 -25.329533]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/1_4_7.jpg
# Actual Results: [4.0, 7.0]
# Predicted Results: [[-6.0412593  2.2394404]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_15_6.jpg
# Actual Results: [15.0, 6.0]
# Predicted Results: [[ 6.462901 -3.155094]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/4_2_12.jpg
# Actual Results: [2.0, 12.0]
# Predicted Results: [[ 8.597658 15.164081]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_15_6.jpg
# Actual Results: [15.0, 6.0]
# Predicted Results: [[-7.824945  -3.7869995]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/14_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[ 3.737482 -5.001835]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/14_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[23.704952 14.904583]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[ -9.521876 -16.496796]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_5_5.jpg
# Actual Results: [5.0, 5.0]
# Predicted Results: [[-10.0713215 -17.985243 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/5_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[35.273148 -6.093274]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/19_0_7.jpg
# Actual Results: [0.0, 7.0]
# Predicted Results: [[17.134977   1.5754533]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_2_14.jpg
# Actual Results: [2.0, 14.0]
# Predicted Results: [[-6.188137 -9.14345 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Image: Hey-Waldo-master/64/waldo/19_0_7.jpg
# Actual Results: [0.0, 7.0]
# Predicted Results: [[-12.452766  -7.009547]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/16_10_4.jpg
# Actual Results: [10.0, 4.0]
# Predicted Results: [[ 6.031236 -5.919337]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_2_15.jpg
# Actual Results: [2.0, 15.0]
# Predicted Results: [[21.303932   4.6227956]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/9_9_5.jpg
# Actual Results: [9.0, 5.0]
# Predicted Results: [[34.115913 15.578665]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_0_12.jpg
# Actual Results: [0.0, 12.0]
# Predicted Results: [[32.492954 19.472313]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[-57.37982  -31.610353]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/11_6_11.jpg
# Actual Results: [6.0, 11.0]
# Predicted Results: [[ -3.5849242 -16.537354 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/2_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[6.5579453 7.433178 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/9_0_12.jpg
# Actual Results: [0.0, 12.0]
# Predicted Results: [[24.437008   4.3049808]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_5_5.jpg
# Actual Results: [5.0, 5.0]
# Predicted Results: [[ 20.350029 -11.375352]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/5_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[ -2.8112414 -19.725428 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/10_15_4.jpg
# Actual Results: [15.0, 4.0]
# Predicted Results: [[ 15.016959 -19.330044]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_5_2.jpg
# Actual Results: [5.0, 2.0]
# Predicted Results: [[ -1.3438125 -20.836895 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/12_2_2.jpg
# Actual Results: [2.0, 2.0]
# Predicted Results: [[-18.14499  -21.124977]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/12_2_1.jpg
# Actual Results: [2.0, 1.0]
# Predicted Results: [[  1.6352681 -12.553424 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_14_7.jpg
# Actual Results: [14.0, 7.0]
# Predicted Results: [[10.552667    0.08364085]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/17_13_5.jpg
# Actual Results: [13.0, 5.0]
# Predicted Results: [[10.69884    -0.94740134]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/11_6_11.jpg
# Actual Results: [6.0, 11.0]
# Predicted Results: [[47.890446 25.427912]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/12_2_1.jpg
# Actual Results: [2.0, 1.0]
# Predicted Results: [[ -8.144906 -16.997114]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/12_2_1.jpg
# Actual Results: [2.0, 1.0]
# Predicted Results: [[  3.171348 -17.46737 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/16_10_4.jpg
# Actual Results: [10.0, 4.0]
# Predicted Results: [[ 6.031236 -5.919337]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_14_7.jpg
# Actual Results: [14.0, 7.0]
# Predicted Results: [[-5.891837  -5.7138495]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/1_4_6.jpg
# Actual Results: [4.0, 6.0]
# Predicted Results: [[ -9.815095 -55.373363]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_0_12.jpg
# Actual Results: [0.0, 12.0]
# Predicted Results: [[26.14425   5.305646]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/12_3_12.jpg
# Actual Results: [3.0, 12.0]
# Predicted Results: [[ -7.649317 -15.927102]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_5_3.jpg
# Actual Results: [5.0, 3.0]
# Predicted Results: [[ 4.2190614 -1.9253215]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_5_3.jpg
# Actual Results: [5.0, 3.0]
# Predicted Results: [[ 4.2190614 -1.9253215]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/2_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[35.273148 -6.093274]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_2_14.jpg
# Actual Results: [2.0, 14.0]
# Predicted Results: [[-6.188137 -9.14345 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[  3.1558988 -22.202316 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/6_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[ 14.964595 -25.172419]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/6_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[ 14.964595 -25.172419]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64/waldo/19_0_6.jpg
# Actual Results: [0.0, 6.0]
# Predicted Results: [[  3.649272 -11.278035]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_2_15.jpg
# Actual Results: [2.0, 15.0]
# Predicted Results: [[-32.464317 -25.924028]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/10_15_4.jpg
# Actual Results: [15.0, 4.0]
# Predicted Results: [[ 15.016959 -19.330044]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_14_7.jpg
# Actual Results: [14.0, 7.0]
# Predicted Results: [[43.46587  21.298431]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/1_4_6.jpg
# Actual Results: [4.0, 6.0]
# Predicted Results: [[-9.980138  -6.5161667]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_0_10.jpg
# Actual Results: [0.0, 10.0]
# Predicted Results: [[11.005692   1.8967766]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/4_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[38.628223  8.176227]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_0_11.jpg
# Actual Results: [0.0, 11.0]
# Predicted Results: [[-8.682699 19.06496 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_9_5.jpg
# Actual Results: [9.0, 5.0]
# Predicted Results: [[-0.5118721  7.6138616]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/2_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[-3.956001 -4.381799]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64-copy/notwaldo/1_0_10.jpg
# Actual Results: [-64, -64]
# Predicted Results: [[-48.549236 -62.519226]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/19_0_7.jpg
# Actual Results: [0.0, 7.0]
# Predicted Results: [[26.446602 18.607824]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/19_0_6.jpg
# Actual Results: [0.0, 6.0]
# Predicted Results: [[  3.649272 -11.278035]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/6_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[ -3.4591143 -10.621502 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_15_6.jpg
# Actual Results: [15.0, 6.0]
# Predicted Results: [[ 6.462901 -3.155094]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/11_6_11.jpg
# Actual Results: [6.0, 11.0]
# Predicted Results: [[33.951508   1.2022774]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_5_2.jpg
# Actual Results: [5.0, 2.0]
# Predicted Results: [[ 15.5378   -12.023462]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/11_6_11.jpg
# Actual Results: [6.0, 11.0]
# Predicted Results: [[33.951508   1.2022774]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/4_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[31.69754 34.32759]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/4_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[31.69754 34.32759]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/6_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[ 14.964595 -25.172419]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_5_5.jpg
# Actual Results: [5.0, 5.0]
# Predicted Results: [[-10.0713215 -17.985243 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[-57.37982  -31.610353]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/3_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[29.390724  -1.2161139]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/4_2_12.jpg
# Actual Results: [2.0, 12.0]
# Predicted Results: [[-20.61142  25.41609]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_14_6.jpg
# Actual Results: [14.0, 6.0]
# Predicted Results: [[25.224548 -8.477332]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_0_10.jpg
# Actual Results: [0.0, 10.0]
# Predicted Results: [[11.005692   1.8967766]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/11_6_11.jpg
# Actual Results: [6.0, 11.0]
# Predicted Results: [[ -3.5849242 -16.537354 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/17_13_5.jpg
# Actual Results: [13.0, 5.0]
# Predicted Results: [[10.69884    -0.94740134]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_5_3.jpg
# Actual Results: [5.0, 3.0]
# Predicted Results: [[ 4.2190614 -1.9253215]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/14_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[23.704952 14.904583]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_2_15.jpg
# Actual Results: [2.0, 15.0]
# Predicted Results: [[38.816643 14.112361]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64/waldo/12_3_12.jpg
# Actual Results: [3.0, 12.0]
# Predicted Results: [[-48.244617 -70.03161 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/1_4_7.jpg
# Actual Results: [4.0, 7.0]
# Predicted Results: [[8.366539   0.28010157]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/16_10_4.jpg
# Actual Results: [10.0, 4.0]
# Predicted Results: [[38.803436   1.2091888]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/2_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[31.165857 14.265556]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_5_2.jpg
# Actual Results: [5.0, 2.0]
# Predicted Results: [[ -1.3438125 -20.836895 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/4_2_12.jpg
# Actual Results: [2.0, 12.0]
# Predicted Results: [[28.414469  -3.3929257]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/2_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[11.175315  -2.2395463]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_6_2.jpg
# Actual Results: [6.0, 2.0]
# Predicted Results: [[  1.9578488 -10.797435 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/10_15_4.jpg
# Actual Results: [15.0, 4.0]
# Predicted Results: [[28.339859 -4.547207]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/14_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[23.704952 14.904583]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/16_10_4.jpg
# Actual Results: [10.0, 4.0]
# Predicted Results: [[38.803436   1.2091888]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_5_2.jpg
# Actual Results: [5.0, 2.0]
# Predicted Results: [[28.239277 -7.395597]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/10_15_4.jpg
# Actual Results: [15.0, 4.0]
# Predicted Results: [[28.339859 -4.547207]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/5_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[11.175315  -2.2395463]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64/waldo/6_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[ -3.4591143 -10.621502 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/6_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[ 14.964595 -25.172419]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[ -9.186456 -10.888293]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[-57.37982  -31.610353]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_6_3.jpg
# Actual Results: [6.0, 3.0]
# Predicted Results: [[30.811079  8.402409]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/2_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[-3.956001 -4.381799]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64/waldo/7_12_5.jpg
# Actual Results: [12.0, 5.0]
# Predicted Results: [[ -5.895302 -15.182343]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_6_2.jpg
# Actual Results: [6.0, 2.0]
# Predicted Results: [[18.711046 10.363137]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_15_6.jpg
# Actual Results: [15.0, 6.0]
# Predicted Results: [[-7.824945  -3.7869995]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/9_5_5.jpg
# Actual Results: [5.0, 5.0]
# Predicted Results: [[18.702522 -8.157995]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_14_6.jpg
# Actual Results: [14.0, 6.0]
# Predicted Results: [[-54.0578   -61.529743]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/12_3_12.jpg
# Actual Results: [3.0, 12.0]
# Predicted Results: [[ -7.649317 -15.927102]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/3_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[ -3.4591143 -10.621502 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/1_4_7.jpg
# Actual Results: [4.0, 7.0]
# Predicted Results: [[-6.0412593  2.2394404]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_14_6.jpg
# Actual Results: [14.0, 6.0]
# Predicted Results: [[-54.0578   -61.529743]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/9_5_5.jpg
# Actual Results: [5.0, 5.0]
# Predicted Results: [[18.702522 -8.157995]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_0_12.jpg
# Actual Results: [0.0, 12.0]
# Predicted Results: [[26.14425   5.305646]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/12_2_1.jpg
# Actual Results: [2.0, 1.0]
# Predicted Results: [[  3.171348 -17.46737 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_6_3.jpg
# Actual Results: [6.0, 3.0]
# Predicted Results: [[ -2.754748 -37.01714 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/4_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[38.628223  8.176227]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/19_0_7.jpg
# Actual Results: [0.0, 7.0]
# Predicted Results: [[17.134977   1.5754533]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_1_1.jpg
# Actual Results: [1.0, 1.0]
# Predicted Results: [[7.7947965 9.820015 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/2_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[11.175315  -2.2395463]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_9_5.jpg
# Actual Results: [9.0, 5.0]
# Predicted Results: [[-0.5118721  7.6138616]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_5_3.jpg
# Actual Results: [5.0, 3.0]
# Predicted Results: [[-2.9952195  5.660495 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/1_4_7.jpg
# Actual Results: [4.0, 7.0]
# Predicted Results: [[22.387594  2.16292 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/6_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[ -3.4591143 -10.621502 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_6_2.jpg
# Actual Results: [6.0, 2.0]
# Predicted Results: [[  1.9578488 -10.797435 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_15_7.jpg
# Actual Results: [15.0, 7.0]
# Predicted Results: [[ 12.593159 -10.474676]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_15_7.jpg
# Actual Results: [15.0, 7.0]
# Predicted Results: [[19.271032  -7.2173276]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/9_0_11.jpg
# Actual Results: [0.0, 11.0]
# Predicted Results: [[ 6.696508 -8.53674 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_1_1.jpg
# Actual Results: [1.0, 1.0]
# Predicted Results: [[7.7947965 9.820015 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_6_2.jpg
# Actual Results: [6.0, 2.0]
# Predicted Results: [[  1.9578488 -10.797435 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_6_3.jpg
# Actual Results: [6.0, 3.0]
# Predicted Results: [[  6.324483 -13.846298]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_0_10.jpg
# Actual Results: [0.0, 10.0]
# Predicted Results: [[11.005692   1.8967766]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/9_5_5.jpg
# Actual Results: [5.0, 5.0]
# Predicted Results: [[18.702522 -8.157995]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/12_3_12.jpg
# Actual Results: [3.0, 12.0]
# Predicted Results: [[-48.244617 -70.03161 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/12_2_2.jpg
# Actual Results: [2.0, 2.0]
# Predicted Results: [[ 5.881581  -1.4955701]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/4_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[31.69754 34.32759]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/1_4_6.jpg
# Actual Results: [4.0, 6.0]
# Predicted Results: [[ 36.64828  -22.286839]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_5_2.jpg
# Actual Results: [5.0, 2.0]
# Predicted Results: [[28.239277 -7.395597]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/5_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[-3.956001 -4.381799]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_1_1.jpg
# Actual Results: [1.0, 1.0]
# Predicted Results: [[ -0.05904783 -24.720705  ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_6_3.jpg
# Actual Results: [6.0, 3.0]
# Predicted Results: [[  6.324483 -13.846298]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_6_3.jpg
# Actual Results: [6.0, 3.0]
# Predicted Results: [[30.811079  8.402409]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/16_10_4.jpg
# Actual Results: [10.0, 4.0]
# Predicted Results: [[38.803436   1.2091888]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/14_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[23.704952 14.904583]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_15_7.jpg
# Actual Results: [15.0, 7.0]
# Predicted Results: [[19.271032  -7.2173276]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_14_6.jpg
# Actual Results: [14.0, 6.0]
# Predicted Results: [[-54.0578   -61.529743]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_6_2.jpg
# Actual Results: [6.0, 2.0]
# Predicted Results: [[18.711046 10.363137]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/14_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[-1.4413414 -4.5725775]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Image: Hey-Waldo-master/64/waldo/6_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[ -3.4591143 -10.621502 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/6_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[ 14.964595 -25.172419]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/12_3_12.jpg
# Actual Results: [3.0, 12.0]
# Predicted Results: [[-48.244617 -70.03161 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/16_10_4.jpg
# Actual Results: [10.0, 4.0]
# Predicted Results: [[38.803436   1.2091888]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_5_3.jpg
# Actual Results: [5.0, 3.0]
# Predicted Results: [[12.163425   6.8978443]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_15_7.jpg
# Actual Results: [15.0, 7.0]
# Predicted Results: [[19.271032  -7.2173276]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_1_1.jpg
# Actual Results: [1.0, 1.0]
# Predicted Results: [[7.7947965 9.820015 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_15_6.jpg
# Actual Results: [15.0, 6.0]
# Predicted Results: [[22.72917  10.523624]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_5_3.jpg
# Actual Results: [5.0, 3.0]
# Predicted Results: [[12.163425   6.8978443]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_9_5.jpg
# Actual Results: [9.0, 5.0]
# Predicted Results: [[14.581773  -5.1906223]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/2_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[ -2.8112414 -19.725428 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/5_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[-3.956001 -4.381799]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_0_12.jpg
# Actual Results: [0.0, 12.0]
# Predicted Results: [[26.14425   5.305646]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_1_1.jpg
# Actual Results: [1.0, 1.0]
# Predicted Results: [[7.7947965 9.820015 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/9_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[17.808676  3.692492]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/4_2_12.jpg
# Actual Results: [2.0, 12.0]
# Predicted Results: [[28.414469  -3.3929257]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/5_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[ -2.8112414 -19.725428 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_14_6.jpg
# Actual Results: [14.0, 6.0]
# Predicted Results: [[  9.965958 -15.149527]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_5_3.jpg
# Actual Results: [5.0, 3.0]
# Predicted Results: [[-2.9952195  5.660495 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/4_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[31.69754 34.32759]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Image: Hey-Waldo-master/64/waldo/4_2_12.jpg
# Actual Results: [2.0, 12.0]
# Predicted Results: [[-20.61142  25.41609]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_5_5.jpg
# Actual Results: [5.0, 5.0]
# Predicted Results: [[-10.0713215 -17.985243 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/3_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[29.390724  -1.2161139]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_9_5.jpg
# Actual Results: [9.0, 5.0]
# Predicted Results: [[-0.5118721  7.6138616]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_14_6.jpg
# Actual Results: [14.0, 6.0]
# Predicted Results: [[-54.0578   -61.529743]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_5_3.jpg
# Actual Results: [5.0, 3.0]
# Predicted Results: [[12.163425   6.8978443]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_5_2.jpg
# Actual Results: [5.0, 2.0]
# Predicted Results: [[28.239277 -7.395597]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_2_15.jpg
# Actual Results: [2.0, 15.0]
# Predicted Results: [[38.816643 14.112361]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/1_4_6.jpg
# Actual Results: [4.0, 6.0]
# Predicted Results: [[ -9.815095 -55.373363]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/12_2_2.jpg
# Actual Results: [2.0, 2.0]
# Predicted Results: [[-18.14499  -21.124977]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/5_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[11.175315  -2.2395463]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/5_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[31.165857 14.265556]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[-57.37982  -31.610353]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/12_3_12.jpg
# Actual Results: [3.0, 12.0]
# Predicted Results: [[ -7.649317 -15.927102]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_14_6.jpg
# Actual Results: [14.0, 6.0]
# Predicted Results: [[-54.0578   -61.529743]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/2_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[11.175315  -2.2395463]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/5_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[35.273148 -6.093274]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[  3.1558988 -22.202316 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/14_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[23.704952 14.904583]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_15_6.jpg
# Actual Results: [15.0, 6.0]
# Predicted Results: [[-7.824945  -3.7869995]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/14_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[ 3.737482 -5.001835]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_14_6.jpg
# Actual Results: [14.0, 6.0]
# Predicted Results: [[25.224548 -8.477332]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_6_2.jpg
# Actual Results: [6.0, 2.0]
# Predicted Results: [[18.711046 10.363137]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/9_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[17.808676  3.692492]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_2_15.jpg
# Actual Results: [2.0, 15.0]
# Predicted Results: [[-32.464317 -25.924028]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/3_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[ 14.964595 -25.172419]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_15_6.jpg
# Actual Results: [15.0, 6.0]
# Predicted Results: [[-7.824945  -3.7869995]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[ -9.521876 -16.496796]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_5_3.jpg
# Actual Results: [5.0, 3.0]
# Predicted Results: [[ 4.2190614 -1.9253215]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_5_3.jpg
# Actual Results: [5.0, 3.0]
# Predicted Results: [[12.163425   6.8978443]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64/waldo/1_4_6.jpg
# Actual Results: [4.0, 6.0]
# Predicted Results: [[-9.980138  -6.5161667]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/5_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[11.175315  -2.2395463]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/2_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[31.165857 14.265556]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_14_6.jpg
# Actual Results: [14.0, 6.0]
# Predicted Results: [[-54.0578   -61.529743]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_14_6.jpg
# Actual Results: [14.0, 6.0]
# Predicted Results: [[  9.965958 -15.149527]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_2_15.jpg
# Actual Results: [2.0, 15.0]
# Predicted Results: [[38.816643 14.112361]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/5_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[35.273148 -6.093274]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/4_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[38.628223  8.176227]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_1_1.jpg
# Actual Results: [1.0, 1.0]
# Predicted Results: [[ -0.05904783 -24.720705  ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/16_10_4.jpg
# Actual Results: [10.0, 4.0]
# Predicted Results: [[11.4407425 -6.6715107]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64-copy/notwaldo/1_1_7.jpg
# Actual Results: [-64, -64]
# Predicted Results: [[-59.437256 -34.81782 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/11_6_11.jpg
# Actual Results: [6.0, 11.0]
# Predicted Results: [[33.951508   1.2022774]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_14_7.jpg
# Actual Results: [14.0, 7.0]
# Predicted Results: [[-5.891837  -5.7138495]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_9_5.jpg
# Actual Results: [9.0, 5.0]
# Predicted Results: [[-0.5118721  7.6138616]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/19_0_6.jpg
# Actual Results: [0.0, 6.0]
# Predicted Results: [[  3.649272 -11.278035]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_2_14.jpg
# Actual Results: [2.0, 14.0]
# Predicted Results: [[-6.188137 -9.14345 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/5_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[31.165857 14.265556]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/5_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[31.165857 14.265556]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_1_1.jpg
# Actual Results: [1.0, 1.0]
# Predicted Results: [[ -0.05904783 -24.720705  ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_6_3.jpg
# Actual Results: [6.0, 3.0]
# Predicted Results: [[  6.324483 -13.846298]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/16_10_4.jpg
# Actual Results: [10.0, 4.0]
# Predicted Results: [[ 6.031236 -5.919337]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_5_5.jpg
# Actual Results: [5.0, 5.0]
# Predicted Results: [[-10.0713215 -17.985243 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_6_3.jpg
# Actual Results: [6.0, 3.0]
# Predicted Results: [[30.811079  8.402409]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/1_4_7.jpg
# Actual Results: [4.0, 7.0]
# Predicted Results: [[8.366539   0.28010157]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_5_5.jpg
# Actual Results: [5.0, 5.0]
# Predicted Results: [[ 20.350029 -11.375352]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/2_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[31.165857 14.265556]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/19_0_7.jpg
# Actual Results: [0.0, 7.0]
# Predicted Results: [[17.134977   1.5754533]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/1_4_7.jpg
# Actual Results: [4.0, 7.0]
# Predicted Results: [[8.366539   0.28010157]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_9_5.jpg
# Actual Results: [9.0, 5.0]
# Predicted Results: [[14.581773  -5.1906223]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/17_13_5.jpg
# Actual Results: [13.0, 5.0]
# Predicted Results: [[34.755344 18.03367 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/12_3_12.jpg
# Actual Results: [3.0, 12.0]
# Predicted Results: [[ -7.649317 -15.927102]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/19_0_6.jpg
# Actual Results: [0.0, 6.0]
# Predicted Results: [[  3.649272 -11.278035]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/5_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[6.5579453 7.433178 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/6_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[ 14.964595 -25.172419]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/2_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[35.273148 -6.093274]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/4_2_12.jpg
# Actual Results: [2.0, 12.0]
# Predicted Results: [[28.414469  -3.3929257]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_5_2.jpg
# Actual Results: [5.0, 2.0]
# Predicted Results: [[ -1.3438125 -20.836895 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/11_6_11.jpg
# Actual Results: [6.0, 11.0]
# Predicted Results: [[33.951508   1.2022774]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/19_0_6.jpg
# Actual Results: [0.0, 6.0]
# Predicted Results: [[ 9.12921   -1.6775827]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/17_13_5.jpg
# Actual Results: [13.0, 5.0]
# Predicted Results: [[34.755344 18.03367 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/5_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[31.165857 14.265556]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/16_10_4.jpg
# Actual Results: [10.0, 4.0]
# Predicted Results: [[11.4407425 -6.6715107]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_2_14.jpg
# Actual Results: [2.0, 14.0]
# Predicted Results: [[-69.36969  -44.962788]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/4_2_12.jpg
# Actual Results: [2.0, 12.0]
# Predicted Results: [[-20.61142  25.41609]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/12_2_1.jpg
# Actual Results: [2.0, 1.0]
# Predicted Results: [[  3.171348 -17.46737 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/12_2_2.jpg
# Actual Results: [2.0, 2.0]
# Predicted Results: [[ 0.52303904 -4.3236833 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/12_2_1.jpg
# Actual Results: [2.0, 1.0]
# Predicted Results: [[  3.171348 -17.46737 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_15_7.jpg
# Actual Results: [15.0, 7.0]
# Predicted Results: [[ 12.593159 -10.474676]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/9_0_11.jpg
# Actual Results: [0.0, 11.0]
# Predicted Results: [[ 6.696508 -8.53674 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_6_2.jpg
# Actual Results: [6.0, 2.0]
# Predicted Results: [[18.711046 10.363137]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/12_3_12.jpg
# Actual Results: [3.0, 12.0]
# Predicted Results: [[28.565845   4.1631646]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/2_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[31.165857 14.265556]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/19_0_7.jpg
# Actual Results: [0.0, 7.0]
# Predicted Results: [[26.446602 18.607824]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/9_5_5.jpg
# Actual Results: [5.0, 5.0]
# Predicted Results: [[18.702522 -8.157995]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/2_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[ -2.8112414 -19.725428 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/4_2_12.jpg
# Actual Results: [2.0, 12.0]
# Predicted Results: [[ 8.597658 15.164081]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_15_7.jpg
# Actual Results: [15.0, 7.0]
# Predicted Results: [[19.271032  -7.2173276]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/14_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[-1.4413414 -4.5725775]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/4_2_12.jpg
# Actual Results: [2.0, 12.0]
# Predicted Results: [[28.414469  -3.3929257]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_5_3.jpg
# Actual Results: [5.0, 3.0]
# Predicted Results: [[-2.9952195  5.660495 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_1_1.jpg
# Actual Results: [1.0, 1.0]
# Predicted Results: [[7.7947965 9.820015 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_5_5.jpg
# Actual Results: [5.0, 5.0]
# Predicted Results: [[ 20.350029 -11.375352]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_5_3.jpg
# Actual Results: [5.0, 3.0]
# Predicted Results: [[ 4.2190614 -1.9253215]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_1_1.jpg
# Actual Results: [1.0, 1.0]
# Predicted Results: [[7.7947965 9.820015 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_2_14.jpg
# Actual Results: [2.0, 14.0]
# Predicted Results: [[-69.36969  -44.962788]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/5_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[ -2.8112414 -19.725428 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_5_3.jpg
# Actual Results: [5.0, 3.0]
# Predicted Results: [[-2.9952195  5.660495 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/2_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[11.175315  -2.2395463]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/2_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[31.165857 14.265556]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/12_3_12.jpg
# Actual Results: [3.0, 12.0]
# Predicted Results: [[28.565845   4.1631646]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_0_10.jpg
# Actual Results: [0.0, 10.0]
# Predicted Results: [[-14.597304   -3.0742133]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/11_6_11.jpg
# Actual Results: [6.0, 11.0]
# Predicted Results: [[ -3.5849242 -16.537354 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# ...
# Actual Results: [0.0, 12.0]
# Predicted Results: [[24.437008   4.3049808]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/9_0_11.jpg
# Actual Results: [0.0, 11.0]
# Predicted Results: [[ 6.696508 -8.53674 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/19_0_7.jpg
# Actual Results: [0.0, 7.0]
# Predicted Results: [[-12.452766  -7.009547]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_14_7.jpg
# Actual Results: [14.0, 7.0]
# Predicted Results: [[-5.891837  -5.7138495]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/11_6_11.jpg
# Actual Results: [6.0, 11.0]
# Predicted Results: [[ -3.5849242 -16.537354 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[ -9.186456 -10.888293]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Image: Hey-Waldo-master/64/waldo/10_15_4.jpg
# Actual Results: [15.0, 4.0]
# Predicted Results: [[-12.73593  -28.680162]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/5_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[35.273148 -6.093274]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_1_1.jpg
# Actual Results: [1.0, 1.0]
# Predicted Results: [[ -0.05904783 -24.720705  ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_2_15.jpg
# Actual Results: [2.0, 15.0]
# Predicted Results: [[38.816643 14.112361]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
#
# Image: Hey-Waldo-master/64/waldo/12_3_12.jpg
# Actual Results: [3.0, 12.0]
# Predicted Results: [[-48.244617 -70.03161 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_5_2.jpg
# Actual Results: [5.0, 2.0]
# Predicted Results: [[ 15.5378   -12.023462]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/7_12_5.jpg
# Actual Results: [12.0, 5.0]
# Predicted Results: [[15.657208  8.930955]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/11_6_11.jpg
# Actual Results: [6.0, 11.0]
# Predicted Results: [[ -3.5849242 -16.537354 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_1_1.jpg
# Actual Results: [1.0, 1.0]
# Predicted Results: [[ -0.05904783 -24.720705  ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_14_6.jpg
# Actual Results: [14.0, 6.0]
# Predicted Results: [[25.224548 -8.477332]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/12_3_12.jpg
# Actual Results: [3.0, 12.0]
# Predicted Results: [[28.565845   4.1631646]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#
# Image: Hey-Waldo-master/64/waldo/2_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[6.5579453 7.433178 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/4_2_12.jpg
# Actual Results: [2.0, 12.0]
# Predicted Results: [[ 8.597658 15.164081]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/4_2_12.jpg
# Actual Results: [2.0, 12.0]
# Predicted Results: [[28.414469  -3.3929257]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/12_2_1.jpg
# Actual Results: [2.0, 1.0]
# Predicted Results: [[  3.171348 -17.46737 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/12_2_1.jpg
# Actual Results: [2.0, 1.0]
# Predicted Results: [[ -8.144906 -16.997114]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_1_1.jpg
# Actual Results: [1.0, 1.0]
# Predicted Results: [[19.09393    3.8352137]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_6_3.jpg
# Actual Results: [6.0, 3.0]
# Predicted Results: [[ -2.754748 -37.01714 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/6_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[ -3.4591143 -10.621502 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/9_0_11.jpg
# Actual Results: [0.0, 11.0]
# Predicted Results: [[ 6.696508 -8.53674 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/1_4_7.jpg
# Actual Results: [4.0, 7.0]
# Predicted Results: [[22.387594  2.16292 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/11_6_11.jpg
# Actual Results: [6.0, 11.0]
# Predicted Results: [[ -3.5849242 -16.537354 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/10_15_4.jpg
# Actual Results: [15.0, 4.0]
# Predicted Results: [[ 15.016959 -19.330044]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_0_12.jpg
# Actual Results: [0.0, 12.0]
# Predicted Results: [[32.492954 19.472313]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/2_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[6.5579453 7.433178 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_5_2.jpg
# Actual Results: [5.0, 2.0]
# Predicted Results: [[ 15.5378   -12.023462]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/14_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[ 3.737482 -5.001835]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_9_5.jpg
# Actual Results: [9.0, 5.0]
# Predicted Results: [[14.581773  -5.1906223]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_9_5.jpg
# Actual Results: [9.0, 5.0]
# Predicted Results: [[14.581773  -5.1906223]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/19_0_6.jpg
# Actual Results: [0.0, 6.0]
# Predicted Results: [[  3.649272 -11.278035]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/4_2_12.jpg
# Actual Results: [2.0, 12.0]
# Predicted Results: [[28.414469  -3.3929257]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_0_12.jpg
# Actual Results: [0.0, 12.0]
# Predicted Results: [[26.14425   5.305646]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/10_15_4.jpg
# Actual Results: [15.0, 4.0]
# Predicted Results: [[28.339859 -4.547207]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/3_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[29.390724  -1.2161139]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_5_3.jpg
# Actual Results: [5.0, 3.0]
# Predicted Results: [[-2.9952195  5.660495 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_14_7.jpg
# Actual Results: [14.0, 7.0]
# Predicted Results: [[43.46587  21.298431]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_0_12.jpg
# Actual Results: [0.0, 12.0]
# Predicted Results: [[32.492954 19.472313]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/14_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[-1.4413414 -4.5725775]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[-57.37982  -31.610353]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_5_5.jpg
# Actual Results: [5.0, 5.0]
# Predicted Results: [[ 20.350029 -11.375352]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_14_6.jpg
# Actual Results: [14.0, 6.0]
# Predicted Results: [[25.224548 -8.477332]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/10_15_4.jpg
# Actual Results: [15.0, 4.0]
# Predicted Results: [[ 15.016959 -19.330044]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/18_14_7.jpg
# Actual Results: [14.0, 7.0]
# Predicted Results: [[-5.891837  -5.7138495]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_6_2.jpg
# Actual Results: [6.0, 2.0]
# Predicted Results: [[18.711046 10.363137]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_2_14.jpg
# Actual Results: [2.0, 14.0]
# Predicted Results: [[-6.188137 -9.14345 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/11_6_11.jpg
# Actual Results: [6.0, 11.0]
# Predicted Results: [[ -3.5849242 -16.537354 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_5_3.jpg
# Actual Results: [5.0, 3.0]
# Predicted Results: [[12.163425   6.8978443]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/1_4_7.jpg
# Actual Results: [4.0, 7.0]
# Predicted Results: [[8.366539   0.28010157]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/11_6_11.jpg
# Actual Results: [6.0, 11.0]
# Predicted Results: [[33.951508   1.2022774]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/11_6_11.jpg
# Actual Results: [6.0, 11.0]
# Predicted Results: [[33.951508   1.2022774]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/1_4_7.jpg
# Actual Results: [4.0, 7.0]
# Predicted Results: [[8.366539   0.28010157]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_6_2.jpg
# Actual Results: [6.0, 2.0]
# Predicted Results: [[18.711046 10.363137]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_0_10.jpg
# Actual Results: [0.0, 10.0]
# Predicted Results: [[11.005692   1.8967766]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[-57.37982  -31.610353]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[ -9.186456 -10.888293]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_6_3.jpg
# Actual Results: [6.0, 3.0]
# Predicted Results: [[  6.324483 -13.846298]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_1_1.jpg
# Actual Results: [1.0, 1.0]
# Predicted Results: [[19.09393    3.8352137]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/16_10_4.jpg
# Actual Results: [10.0, 4.0]
# Predicted Results: [[11.4407425 -6.6715107]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_0_12.jpg
# Actual Results: [0.0, 12.0]
# Predicted Results: [[32.492954 19.472313]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/16_10_4.jpg
# Actual Results: [10.0, 4.0]
# Predicted Results: [[11.4407425 -6.6715107]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/2_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[11.175315  -2.2395463]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_0_12.jpg
# Actual Results: [0.0, 12.0]
# Predicted Results: [[26.14425   5.305646]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/19_0_6.jpg
# Actual Results: [0.0, 6.0]
# Predicted Results: [[32.68685  19.420082]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_9_5.jpg
# Actual Results: [9.0, 5.0]
# Predicted Results: [[-0.5118721  7.6138616]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_14_7.jpg
# Actual Results: [14.0, 7.0]
# Predicted Results: [[43.46587  21.298431]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_0_11.jpg
# Actual Results: [0.0, 11.0]
# Predicted Results: [[-8.682699 19.06496 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_6_2.jpg
# Actual Results: [6.0, 2.0]
# Predicted Results: [[-12.113542 -20.101799]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/4_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[38.628223  8.176227]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/12_2_1.jpg
# Actual Results: [2.0, 1.0]
# Predicted Results: [[ -8.144906 -16.997114]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/1_4_6.jpg
# Actual Results: [4.0, 6.0]
# Predicted Results: [[ -9.815095 -55.373363]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/13_2_11.jpg
# Actual Results: [2.0, 11.0]
# Predicted Results: [[-57.37982  -31.610353]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64/waldo/9_1_12.jpg
# Actual Results: [1.0, 12.0]
# Predicted Results: [[ -9.186456 -10.888293]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/17_13_5.jpg
# Actual Results: [13.0, 5.0]
# Predicted Results: [[34.755344 18.03367 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/6_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[29.390724  -1.2161139]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/5_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[31.165857 14.265556]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/5_7_3.jpg
# Actual Results: [7.0, 3.0]
# Predicted Results: [[31.165857 14.265556]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/17_13_5.jpg
# Actual Results: [13.0, 5.0]
# Predicted Results: [[10.69884    -0.94740134]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/9_0_10.jpg
# Actual Results: [0.0, 10.0]
# Predicted Results: [[11.005692   1.8967766]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_2_15.jpg
# Actual Results: [2.0, 15.0]
# Predicted Results: [[21.303932   4.6227956]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/1_4_7.jpg
# Actual Results: [4.0, 7.0]
# Predicted Results: [[8.366539   0.28010157]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64/waldo/6_15_1.jpg
# Actual Results: [15.0, 1.0]
# Predicted Results: [[ -3.4591143 -10.621502 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/12_2_2.jpg
# Actual Results: [2.0, 2.0]
# Predicted Results: [[-18.14499  -21.124977]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/18_15_6.jpg
# Actual Results: [15.0, 6.0]
# Predicted Results: [[22.72917  10.523624]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/4_2_12.jpg
# Actual Results: [2.0, 12.0]
# Predicted Results: [[ 8.597658 15.164081]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/12_2_2.jpg
# Actual Results: [2.0, 2.0]
# Predicted Results: [[ 5.881581  -1.4955701]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/13_6_2.jpg
# Actual Results: [6.0, 2.0]
# Predicted Results: [[18.711046 10.363137]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/10_15_4.jpg
# Actual Results: [15.0, 4.0]
# Predicted Results: [[ 15.016959 -19.330044]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/18_15_7.jpg
# Actual Results: [15.0, 7.0]
# Predicted Results: [[19.271032  -7.2173276]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/5_2_5.jpg
# Actual Results: [2.0, 5.0]
# Predicted Results: [[35.273148 -6.093274]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/7_12_5.jpg
# Actual Results: [12.0, 5.0]
# Predicted Results: [[  3.7519155 -28.917213 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/19_0_6.jpg
# Actual Results: [0.0, 6.0]
# Predicted Results: [[32.68685  19.420082]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/19_0_7.jpg
# Actual Results: [0.0, 7.0]
# Predicted Results: [[17.134977   1.5754533]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
#
# Image: Hey-Waldo-master/64-bw/waldo/13_6_3.jpg
# Actual Results: [6.0, 3.0]
# Predicted Results: [[ -2.754748 -37.01714 ]]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#
# Image: Hey-Waldo-master/64-gray/waldo/4_2_12.jpg
# Actual Results: [2.0, 12.0]
# Predicted Results: [[ 8.597658 15.164081]]
#
# X Error: nan
# Y Error: -303.38612402713284
